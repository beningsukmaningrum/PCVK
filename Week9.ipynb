# %% [markdown]
# <a href="https://colab.research.google.com/github/beningsukmaningrum/PCVK_Genap_2021/blob/main/Week9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt
from google.colab.patches import cv2_imshow

# %%
kernel = np.ones((5,5), np.uint8)
dilation = cv.dilate(img, kernel, iterations = 1)

plt.subplot(121),plt.imshow(img),plt.title('Citra Awal')
plt.subplot(122),plt.imshow(dilation),plt.title('Citra Hasil Dilasi')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f435f6c4d90>,
#  <matplotlib.image.AxesImage at 0x7f435f599250>,
#  Text(0.5, 1.0, 'Citra Hasil Dilasi'))

# %%
#no 4

kernel = np.ones((5,5), np.uint8)
erosion = cv.morphologyEx(img, cv.MORPH_ERODE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(erosion), plt.title('Cintra Hasil Erosi')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f435f77d550>,
#  <matplotlib.image.AxesImage at 0x7f435f6c4850>,
#  Text(0.5, 1.0, 'Cintra Hasil Erosi'))

# %%
#no 5

kernel = np.ones((5,5), np.uint8)
dilation = cv.morphologyEx(img, cv.MORPH_DILATE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(dilation), plt.title('Cintra Hasil Dilasi')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f435f82c3d0>,
#  <matplotlib.image.AxesImage at 0x7f435f770fd0>,
#  Text(0.5, 1.0, 'Cintra Hasil Dilasi'))

# %%
#No 6

kernel = np.ones((5,5), np.uint8)
erosion = cv.morphologyEx(img, cv.MORPH_ERODE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(erosion), plt.title('Cintra Hasil Erosi')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f435f8db190>,
#  <matplotlib.image.AxesImage at 0x7f435f81fe50>,
#  Text(0.5, 1.0, 'Cintra Hasil Erosi'))

# %%
#No 7

kernel = np.ones((7,7), np.uint8)
opening = cv.morphologyEx(img, cv.MORPH_OPEN, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(opening), plt.title('Cintra Hasil Opening')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f435fa073d0>,
#  <matplotlib.image.AxesImage at 0x7f435f94fc10>,
#  Text(0.5, 1.0, 'Cintra Hasil Opening'))

# %%
#No 7 (Tanpa library)

img = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/j.png')

element = cv.getStructuringElement(cv.MORPH_RECT,(7,7))
erosion_dst = cv.erode(img, element)
opening_dst = cv.dilate(erosion_dst, element)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(opening_dst), plt.title('Cintra Hasil Opening')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f435faa0e90>,
#  <matplotlib.image.AxesImage at 0x7f435f9f6dd0>,
#  Text(0.5, 1.0, 'Cintra Hasil Opening'))

# %%
#No 8

kernel = np.ones((7,7), np.uint8)
closing = cv.morphologyEx(img, cv.MORPH_CLOSE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(closing), plt.title('Cintra Hasil Closing')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f435fcf4950>,
#  <matplotlib.image.AxesImage at 0x7f435fc3e950>,
#  Text(0.5, 1.0, 'Cintra Hasil Closing'))

# %%
#No 8 (Tanpa library)

img = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/j.png')

element = cv.getStructuringElement(cv.MORPH_RECT,(7,7))
dilate_dst = cv.dilate(img, element)
closing_dst = cv.erode(dilate_dst, element)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(closing_dst), plt.title('Cintra Hasil Closing')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f435fccb1d0>,
#  <matplotlib.image.AxesImage at 0x7f435faa08d0>,
#  Text(0.5, 1.0, 'Cintra Hasil Closing'))

# %%
#No 9

kernel = np.ones((3,3), np.uint8)
dilation = cv.dilate(img, kernel, iterations = 1)

plt.subplot(121),plt.imshow(img),plt.title('Citra Awal')
plt.subplot(122),plt.imshow(dilation),plt.title('Citra Hasil Dilasi')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f435f5797d0>,
#  <matplotlib.image.AxesImage at 0x7f435f4e6bd0>,
#  Text(0.5, 1.0, 'Citra Hasil Dilasi'))

# %%
#No 9

kernel = np.ones((5,5), np.uint8)
dilation = cv.dilate(img, kernel, iterations = 1)

plt.subplot(121),plt.imshow(img),plt.title('Citra Awal')
plt.subplot(122),plt.imshow(dilation),plt.title('Citra Hasil Dilasi')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f435fa853d0>,
#  <matplotlib.image.AxesImage at 0x7f435f861a10>,
#  Text(0.5, 1.0, 'Citra Hasil Dilasi'))

# %%
#No 10

kernel = np.ones((3,3), np.uint8)
dilation = cv.dilate(img, kernel, iterations = 1)

plt.subplot(121),plt.imshow(img),plt.title('Citra Awal')
plt.subplot(122),plt.imshow(dilation),plt.title('Citra Hasil Dilasi')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f435f157450>,
#  <matplotlib.image.AxesImage at 0x7f435f119e10>,
#  Text(0.5, 1.0, 'Citra Hasil Dilasi'))

# %%
#No 10

kernel = np.ones((5,5), np.uint8)
dilation = cv.dilate(img, kernel, iterations = 1)

plt.subplot(121),plt.imshow(img),plt.title('Citra Awal')
plt.subplot(122),plt.imshow(dilation),plt.title('Citra Hasil Dilasi')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f435f127390>,
#  <matplotlib.image.AxesImage at 0x7f435f069f50>,
#  Text(0.5, 1.0, 'Citra Hasil Dilasi'))

# %%
# No 11

kernel = np.ones((3,5), np.uint8)
erosion = cv.morphologyEx(img, cv.MORPH_ERODE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(erosion), plt.title('Cintra Hasil Erosi 3 x 5')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f435f0784d0>,
#  <matplotlib.image.AxesImage at 0x7f435efb9f10>,
#  Text(0.5, 1.0, 'Cintra Hasil Erosi 3 x 5'))

# %%
# No 11

kernel = np.ones((5,7), np.uint8)
erosion = cv.morphologyEx(img, cv.MORPH_ERODE, kernel)

plt.subplot(121), plt.imshow(img), plt.title('Citra Awal')
plt.subplot(122), plt.imshow(erosion), plt.title('Cintra Hasil Erosi 5 x 7')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f435efc8490>,
#  <matplotlib.image.AxesImage at 0x7f435ee937d0>,
#  Text(0.5, 1.0, 'Cintra Hasil Erosi 5 x 7'))
